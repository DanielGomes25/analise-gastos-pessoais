# %%
import pandas as pd

df = pd.read_csv('../dados/gastos.csv')
df.head()
# Out:
#    id        data    categoria       descricao  valor
# 0   1  2025-01-05      Salario  Salario Mensal   1800
# 1   2  2025-01-06  Alimentacao    Supermercado   -250
# 2   3  2025-01-07   Transporte            Uber    -35
# 3   4  2025-01-08        Lazer          Cinema    -40
# 4   5  2025-01-10       Contas        Internet   -120
